# %% [markdown]
# # Using the Yelp API (Practice)
# - Amber Kutscher

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open (r"\Users\amber\.secret\yelp_api.json") as f:
    login = json.load(f)

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['API Key'], timeout_s = 5.0)

# %%
# Set our API call parameters and filename before the first call
location = 'Seattle, WA 98101'
term = 'sushi'

# %%
# Use our yelp_api variable's search_query method to perform our API call
sushi_results = yelp.search_query(term = term, location = location)
type(sushi_results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
sushi_seattle = pd.DataFrame(sushi_results['businesses'])
sushi_seattle.head()
# Out:
#                        id                           alias  \
# 0  3hxncVCRPfmKLOyiXKXbDw           sushi-kashiba-seattle
# 1  L8RRAd-JZ0Bd4MER0yyX-g  japonessa-sushi-cocina-seattle
# 2  YSQiqH7RIWORk_Qp-A4SOg                  shiros-seattle
# 3  vs5dhED5Yf8kqPp06OD2QQ                  momiji-seattle
# 4  CwvRIblqSTc1McIE9hwhFA         sushi-kudasai-seattle-2
#
#                      name                                          image_url  \
# 0           Sushi Kashiba  https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-m...
# 1  Japonessa Sushi Cocina  https://s3-media3.fl.yelpcdn.com/bphoto/vucCrk...
# 2                 Shiro's  https://s3-media1.fl.yelpcdn.com/bphoto/Gs9xeF...
# 3                  Momiji  https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6B...
# 4           Sushi Kudasai  https://s3-media2.fl.yelpcdn.com/bphoto/fXSJAz...
#
#    is_closed                                                url  review_count  \
# ...

# %%
sushi_results['total']
# Out:
# 210

# %%
# 210 will require 11 pages
# Assignment only asks for 2 pages
sushi_20 = yelp.search_query(location = location, term = term, offset = 20)

# %%
sushi_20 = pd.DataFrame(sushi_20['businesses'])
sushi_20.head()
# Out:
#                        id                             alias  \
# 0  xTTteSIJ-1-GkzvlU21vIQ  shinya-shokudo-seattle-seattle-2
# 1  xYpw8slGWrhofgwfMX8-tA                  migoto-seattle-4
# 2  bS4nymdYrOozf9LjdPgO5w              sushi-kanpai-seattle
# 3  AjRFPwrBnwW7yQUSIvrcVg    urara-japanese-cuisine-seattle
# 4  cFTq5MmBDPb_VEqQXPw2Dw  wasabi-sushi-and-izakaya-seattle
#
#                        name  \
# 0  Shinya Shokudo - Seattle
# 1                    Migoto
# 2              Sushi Kanpai
# 3    Urara Japanese Cuisine
# 4    Wasabi Sushi & Izakaya
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/uVTjrL...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/MUEJ6y...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/SyXhNJ...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/fLA8Rg...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/u-GfVc...      False
#
# ...

# %%
# Concatenate all of the pages
all_sushi = pd.concat([sushi_seattle, sushi_20],
                     ignore_index=True)
display(all_sushi.head(), all_sushi.tail())
# Out:
#                        id                           alias  \
# 0  3hxncVCRPfmKLOyiXKXbDw           sushi-kashiba-seattle
# 1  L8RRAd-JZ0Bd4MER0yyX-g  japonessa-sushi-cocina-seattle
# 2  YSQiqH7RIWORk_Qp-A4SOg                  shiros-seattle
# 3  vs5dhED5Yf8kqPp06OD2QQ                  momiji-seattle
# 4  CwvRIblqSTc1McIE9hwhFA         sushi-kudasai-seattle-2
#
#                      name                                          image_url  \
# 0           Sushi Kashiba  https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-m...
# 1  Japonessa Sushi Cocina  https://s3-media3.fl.yelpcdn.com/bphoto/vucCrk...
# 2                 Shiro's  https://s3-media1.fl.yelpcdn.com/bphoto/Gs9xeF...
# 3                  Momiji  https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6B...
# 4           Sushi Kudasai  https://s3-media2.fl.yelpcdn.com/bphoto/fXSJAz...
#
#    is_closed                                                url  review_count  \
# ...

# %%
all_sushi.to_json(orient='records')
# Out:
# '[{"id":"3hxncVCRPfmKLOyiXKXbDw","alias":"sushi-kashiba-seattle","name":"Sushi Kashiba","image_url":"https:\\/\\/s3-media2.fl.yelpcdn.com\\/bphoto\\/kDUe-mbgXOzne_HSbKy19g\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/sushi-kashiba-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ","review_count":1382,"categories":[{"alias":"japanese","title":"Japanese"},{"alias":"sushi","title":"Sushi Bars"}],"rating":4.5,"coordinates":{"latitude":47.6099251,"longitude":-122.3415442},"transactions":["delivery"],"price":"$$$$","location":{"address1":"86 Pine St","address2":"Ste 1","address3":"","city":"Seattle","zip_code":"98101","country":"US","state":"WA","display_address":["86 Pine St","Ste 1","Seattle, WA 98101"]},"phone":"+12064418844","display_phone":"(206) 441-8844","distance":586.0441840262},{"id":"L8RRAd-JZ0Bd4MER0yyX-g","alias":"japonessa-sushi-cocina-seattle","name":"Japonessa Sus
# ...
