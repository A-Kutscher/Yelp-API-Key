# %% [markdown]
# # Efficient Yelp API Calls (Core)
# - Amber Kutscher

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open (r"\Users\amber\.secret\yelp_api.json") as f:
    login = json.load(f)

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['API Key'], timeout_s = 5.0)

# %%
# Set our API call parameters and filename before the first call
location = 'Seattle, WA 98101'
term = 'sushi'

# %%
# Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
# Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
# If it does not exist: 
if file_exists == False:
    # CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    # If JSON_FILE included a folder:
    if len(folder) > 0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    # INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    # save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
# If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Seattle-sushi.json not found. Saving empty list to file.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %%
# Use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# How many results total?
results['total']
# Out:
# 210

# %%
results['region']
# Out:
# {'center': {'longitude': -122.33405113220215, 'latitude': 47.611428139373075}}

# %%
results['businesses']
# Out:
# [{'id': 'L8RRAd-JZ0Bd4MER0yyX-g',
#   'alias': 'japonessa-sushi-cocina-seattle',
#   'name': 'Japonessa Sushi Cocina',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vucCrknnlu1RRvRaKWwovQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/japonessa-sushi-cocina-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 5251,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6079793649921,
#    'longitude': -122.339042355669},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1400 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1400 1st Ave', 'Seattle, WA 98101']},
#   'phone': '+12069717979',
#   'display_phone': '(206) 971-7979',
#   'distance': 535.7820404150749},
#  {'id': '3hxncVCRPfmKLOyiXKXbDw',
#   'alias': 'sushi-kashiba-seattle',
#   'name': 'Sushi Kashiba',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-mbgXOzne_HSbKy19g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-kashiba-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 1382,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6099251, 'longitude': -122.3415442},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '86 Pine St',
#    'address2': 'Ste 1',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['86 Pine St', 'Ste 1', 'Seattle, WA 98101']},
#   'phone': '+12064418844',
#   'display_phone': '(206) 441-8844',
#   'distance': 586.0441840262457},
#  {'id': 'CwvRIblqSTc1McIE9hwhFA',
#   'alias': 'sushi-kudasai-seattle-2',
#   'name': 'Sushi Kudasai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fXSJAz7wWvDXKSwgjqfb_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-kudasai-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 145,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.610282, 'longitude': -122.333958},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1420 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1420 5th Ave', 'Seattle, WA 98101']},
#   'phone': '+12066828000',
#   'display_phone': '(206) 682-8000',
#   'distance': 127.63582448126431},
#  {'id': 'YSQiqH7RIWORk_Qp-A4SOg',
#   'alias': 'shiros-seattle',
#   'name': "Shiro's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gs9xeFtJfeXQsZHhSCvB5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shiros-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 2586,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6147782162181,
#    'longitude': -122.347327076057},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$$',
#   'location': {'address1': '2401 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2401 2nd Ave', 'Seattle, WA 98121']},
#   'phone': '+12064439844',
#   'display_phone': '(206) 443-9844',
#   'distance': 1062.6011227519375},
#  {'id': 'vs5dhED5Yf8kqPp06OD2QQ',
#   'alias': 'momiji-seattle',
#   'name': 'Momiji',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6BzYeb8Ris8BcfSyBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/momiji-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 1798,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61482, 'longitude': -122.31657},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1522 12th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1522 12th Ave', 'Seattle, WA 98122']},
#   'phone': '+12064574068',
#   'display_phone': '(206) 457-4068',
#   'distance': 1366.179557238785},
#  {'id': 'L5AL3EIl085kjESUj0POfQ',
#   'alias': 'urban-sushi-kitchen-seattle',
#   'name': 'Urban Sushi Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9zhNuEn_iLnr7w8WrhGfFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/urban-sushi-kitchen-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 158,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61590895201695,
#    'longitude': -122.3371570177856},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2001 8th Ave',
#    'address2': 'Ste 150-C',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2001 8th Ave', 'Ste 150-C', 'Seattle, WA 98121']},
#   'phone': '+12064486953',
#   'display_phone': '(206) 448-6953',
#   'distance': 549.9536705585723},
#  {'id': 'h1Q0Wkx5TUUZeVjJrXTwmQ',
#   'alias': 'chan-seattle-seattle-2',
#   'name': 'Chan Seattle',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5Iry3TBITggXt1MiW5tOA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chan-seattle-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 1010,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.613173, 'longitude': -122.333653},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '724 Pine St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['724 Pine St', 'Seattle, WA 98101']},
#   'phone': '+14256582626',
#   'display_phone': '(425) 658-2626',
#   'distance': 195.38634212928886},
#  {'id': 'EWrDx-M8HJpR0wVJHrflNg',
#   'alias': 'umi-sake-house-seattle',
#   'name': 'Umi Sake House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aNbCmxzlqMQJVn07CM1pAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/umi-sake-house-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 4038,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61339, 'longitude': -122.34597},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2230 1st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2230 1st Ave', 'Seattle, WA 98121']},
#   'phone': '+12063748717',
#   'display_phone': '(206) 374-8717',
#   'distance': 924.8701989970556},
#  {'id': 'OAefcMo0Oq2eSoK2F0ZCOg',
#   'alias': 'sugo-hand-roll-bar-seattle-2',
#   'name': 'Sugo Hand Roll Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lHtYgQlErB4CCMybLTAk8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sugo-hand-roll-bar-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 406,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61053, 'longitude': -122.344383},
#   'transactions': ['restaurant_reservation'],
#   'location': {'address1': '2001 Western Ave',
#    'address2': 'Ste 110',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2001 Western Ave', 'Ste 110', 'Seattle, WA 98121']},
#   'phone': '+12062680172',
#   'display_phone': '(206) 268-0172',
#   'distance': 778.1888972251769},
#  {'id': 'ClAQfNyMp_EuTks0fz-KXg',
#   'alias': 'aburiya-bento-house-seattle-2',
#   'name': 'Aburiya Bento House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ySyh0ErwyHQwT673qpnBPQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aburiya-bento-house-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 402,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.61134, 'longitude': -122.34493},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2100 Western Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2100 Western Ave', 'Seattle, WA 98121']},
#   'phone': '+12064534685',
#   'display_phone': '(206) 453-4685',
#   'distance': 806.7918368003661},
#  {'id': '88I5mTFd8FiW3DW5S6DHQg',
#   'alias': 'noren-sushi-kitchen-and-bar-seattle-2',
#   'name': 'Noren Sushi Kitchen & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aI1jq8K9vhULXGe7Q83t8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noren-sushi-kitchen-and-bar-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 212,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.614225, 'longitude': -122.327007},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '320 E Pike St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['320 E Pike St', 'Seattle, WA 98122']},
#   'phone': '+12063279269',
#   'display_phone': '(206) 327-9269',
#   'distance': 612.8103003824002},
#  {'id': '1_ClzWbou8RORI5Lxt9ewQ',
#   'alias': 'wasabi-sushi-sea-seattle',
#   'name': 'Wasabi Sushi SEA',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rrK0fE-ElJJYAgLZiNTZ7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wasabi-sushi-sea-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 38,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.61518, 'longitude': -122.32856},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1202 Pine St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1202 Pine St', 'Seattle, WA 98101']},
#   'phone': '+12068907056',
#   'display_phone': '(206) 890-7056',
#   'distance': 597.3977445511892},
#  {'id': 'jAgEaQUQMvGC2PsxYjBWOQ',
#   'alias': 'katsu-ya-seattle-seattle',
#   'name': 'Katsu-ya Seattle',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UGZjZevktSlaSjGY7T38Ww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/katsu-ya-seattle-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 267,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.619252, 'longitude': -122.338099},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '122 Westlake Ave N',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98109',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['122 Westlake Ave N', 'Seattle, WA 98109']},
#   'phone': '+12065800080',
#   'display_phone': '(206) 580-0080',
#   'distance': 930.3717501050149},
#  {'id': 'dkZiHbwggWsB3QSQhy2New',
#   'alias': 'rondo-seattle-2',
#   'name': 'Rondo',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8IgsASbhWmQ-WSNFX_TQ6w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rondo-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 494,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'izakaya', 'title': 'Izakaya'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.62082, 'longitude': -122.32066},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '224 Broadway E',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98102',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['224 Broadway E', 'Seattle, WA 98102']},
#   'phone': '+12065882051',
#   'display_phone': '(206) 588-2051',
#   'distance': 1438.9756630675474},
#  {'id': 'LJzT7LMjLdcYNUoDyKjDqw',
#   'alias': 'momiji-slu-seattle',
#   'name': 'Momiji SLU',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ECTMgvmzjIv9zJX7sT0i8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/momiji-slu-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 153,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61756, 'longitude': -122.34089},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '731 Bell St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['731 Bell St', 'Seattle, WA 98121']},
#   'phone': '+12062571304',
#   'display_phone': '(206) 257-1304',
#   'distance': 856.1603787782964},
#  {'id': 'bS4nymdYrOozf9LjdPgO5w',
#   'alias': 'sushi-kanpai-seattle',
#   'name': 'Sushi Kanpai',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SyXhNJoaJxvD8_1H_n32bA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-kanpai-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 404,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.60753315854213,
#    'longitude': -122.3278308718496},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '900 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['900 8th Ave', 'Seattle, WA 98104']},
#   'phone': '+12065882769',
#   'display_phone': '(206) 588-2769',
#   'distance': 636.4089389895656},
#  {'id': 'M5gjalaqrlkVm55RHqiaaA',
#   'alias': 'maneki-seattle',
#   'name': 'Maneki',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r_gCjNFXAwT0HklvX_hGCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maneki-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 1265,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.59974, 'longitude': -122.32614},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '304 6th Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['304 6th Ave S', 'Seattle, WA 98104']},
#   'phone': '+12066222631',
#   'display_phone': '(206) 622-2631',
#   'distance': 1433.640394846921},
#  {'id': 'xYpw8slGWrhofgwfMX8-tA',
#   'alias': 'migoto-seattle-4',
#   'name': 'Migoto',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MUEJ6yrPWrP7glpgy3hmnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/migoto-seattle-4?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 163,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.60673, 'longitude': -122.31649},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '514 12th Ave',
#    'address2': 'Across Seattle University',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['514 12th Ave',
#     'Across Seattle University',
#     'Seattle, WA 98122']},
#   'phone': '+12063291112',
#   'display_phone': '(206) 329-1112',
#   'distance': 1412.3993597319657},
#  {'id': 'tg9Fsdky2V-Bg3xiSIT4sg',
#   'alias': 'taneda-sushi-in-kaiseki-seattle-2',
#   'name': 'Taneda Sushi in Kaiseki',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WXxZwpGXvGOviZLFWLzxbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taneda-sushi-in-kaiseki-seattle-2?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 256,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 47.62063, 'longitude': -122.32134},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '219 Broadway E',
#    'address2': 'Ste 14',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98102',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['219 Broadway E', 'Ste 14', 'Seattle, WA 98102']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1395.9927979803267},
#  {'id': '_wPEVw2gQpySK5GCA3dbsA',
#   'alias': 'tamari-bar-seattle',
#   'name': 'Tamari Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ffvMyBXS-M0wKoXG9rHblg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tamari-bar-seattle?adjust_creative=jh5hXS_D2zcYEgEagqv7NQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jh5hXS_D2zcYEgEagqv7NQ',
#   'review_count': 610,
#   'categories': [{'alias': 'izakaya', 'title': 'Izakaya'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61537, 'longitude': -122.32534},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '500 E Pine St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['500 E Pine St', 'Seattle, WA 98122']},
#   'phone': '+12069798800',
#   'display_phone': '(206) 979-8800',
#   'distance': 793.0951091840761}]

# %%
# How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                  alias  \
# 0   L8RRAd-JZ0Bd4MER0yyX-g         japonessa-sushi-cocina-seattle
# 1   3hxncVCRPfmKLOyiXKXbDw                  sushi-kashiba-seattle
# 2   CwvRIblqSTc1McIE9hwhFA                sushi-kudasai-seattle-2
# 3   YSQiqH7RIWORk_Qp-A4SOg                         shiros-seattle
# 4   vs5dhED5Yf8kqPp06OD2QQ                         momiji-seattle
# 5   L5AL3EIl085kjESUj0POfQ            urban-sushi-kitchen-seattle
# 6   h1Q0Wkx5TUUZeVjJrXTwmQ                 chan-seattle-seattle-2
# 7   EWrDx-M8HJpR0wVJHrflNg                 umi-sake-house-seattle
# 8   OAefcMo0Oq2eSoK2F0ZCOg           sugo-hand-roll-bar-seattle-2
# 9   ClAQfNyMp_EuTks0fz-KXg          aburiya-bento-house-seattle-2
# 10  88I5mTFd8FiW3DW5S6DHQg  noren-sushi-kitchen-and-bar-seattle-2
# 11  1_ClzWbou8RORI5Lxt9ewQ               wasabi-sushi-sea-seattle
# 12  jAgEaQUQMvGC2PsxYjBWOQ               katsu-ya-seattle-seattle
# 13  dkZiHbwggWsB3QSQhy2New                        rondo-seattle-2
# 14  LJzT7LMjLdcYNUoDyKjDqw                     momiji-slu-seattle
# 15  bS4nymdYrOozf9LjdPgO5w                   sushi-kanpai-seattle
# 16  M5gjalaqrlkVm55RHqiaaA                         maneki-seattle
# 17  xYpw8slGWrhofgwfMX8-tA                       migoto-seattle-4
# 18  tg9Fsdky2V-Bg3xiSIT4sg      taneda-sushi-in-kaiseki-seattle-2
# 19  _wPEVw2gQpySK5GCA3dbsA                     tamari-bar-seattle
#
#                          name  \
# 0      Japonessa Sushi Cocina
# 1               Sushi Kashiba
# 2               Sushi Kudasai
# 3                     Shiro's
# 4                      Momiji
# 5         Urban Sushi Kitchen
# 6                Chan Seattle
# 7              Umi Sake House
# 8          Sugo Hand Roll Bar
# 9         Aburiya Bento House
# 10  Noren Sushi Kitchen & Bar
# 11           Wasabi Sushi SEA
# 12           Katsu-ya Seattle
# 13                      Rondo
# 14                 Momiji SLU
# 15               Sushi Kanpai
# 16                     Maneki
# 17                     Migoto
# 18    Taneda Sushi in Kaiseki
# 19                 Tamari Bar
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/vucCrk...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-m...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/fXSJAz...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/Gs9xeF...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6B...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/9zhNuE...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/C5Iry3...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/aNbCmx...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/lHtYgQ...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/ySyh0E...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/aI1jq8...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/rrK0fE...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/UGZjZe...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/8IgsAS...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/ECTMgv...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/SyXhNJ...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/r_gCjN...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/MUEJ6y...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/WXxZwp...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/ffvMyB...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/japonessa-sushi-cocin...          5251
# 1   https://www.yelp.com/biz/sushi-kashiba-seattle...          1382
# 2   https://www.yelp.com/biz/sushi-kudasai-seattle...           145
# 3   https://www.yelp.com/biz/shiros-seattle?adjust...          2586
# 4   https://www.yelp.com/biz/momiji-seattle?adjust...          1798
# 5   https://www.yelp.com/biz/urban-sushi-kitchen-s...           158
# 6   https://www.yelp.com/biz/chan-seattle-seattle-...          1010
# 7   https://www.yelp.com/biz/umi-sake-house-seattl...          4038
# 8   https://www.yelp.com/biz/sugo-hand-roll-bar-se...           406
# 9   https://www.yelp.com/biz/aburiya-bento-house-s...           402
# 10  https://www.yelp.com/biz/noren-sushi-kitchen-a...           212
# 11  https://www.yelp.com/biz/wasabi-sushi-sea-seat...            38
# 12  https://www.yelp.com/biz/katsu-ya-seattle-seat...           267
# 13  https://www.yelp.com/biz/rondo-seattle-2?adjus...           494
# 14  https://www.yelp.com/biz/momiji-slu-seattle?ad...           153
# 15  https://www.yelp.com/biz/sushi-kanpai-seattle?...           404
# 16  https://www.yelp.com/biz/maneki-seattle?adjust...          1265
# 17  https://www.yelp.com/biz/migoto-seattle-4?adju...           163
# 18  https://www.yelp.com/biz/taneda-sushi-in-kaise...           256
# 19  https://www.yelp.com/biz/tamari-bar-seattle?ad...           610
#
#                                            categories  rating  \
# 0   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 1   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 2   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 3   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 4   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 5   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 6   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 8   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 9   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 10  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 11  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 12  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 13  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 14  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 15  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 16  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 17  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 18  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     5.0
# 19         [{'alias': 'izakaya', 'title': 'Izakaya'}]     4.0
#
#                                           coordinates  \
# 0   {'latitude': 47.6079793649921, 'longitude': -1...
# 1   {'latitude': 47.6099251, 'longitude': -122.341...
# 2   {'latitude': 47.610282, 'longitude': -122.333958}
# 3   {'latitude': 47.6147782162181, 'longitude': -1...
# 4     {'latitude': 47.61482, 'longitude': -122.31657}
# 5   {'latitude': 47.61590895201695, 'longitude': -...
# 6   {'latitude': 47.613173, 'longitude': -122.333653}
# 7     {'latitude': 47.61339, 'longitude': -122.34597}
# 8    {'latitude': 47.61053, 'longitude': -122.344383}
# 9     {'latitude': 47.61134, 'longitude': -122.34493}
# 10  {'latitude': 47.614225, 'longitude': -122.327007}
# 11    {'latitude': 47.61518, 'longitude': -122.32856}
# 12  {'latitude': 47.619252, 'longitude': -122.338099}
# 13    {'latitude': 47.62082, 'longitude': -122.32066}
# 14    {'latitude': 47.61756, 'longitude': -122.34089}
# 15  {'latitude': 47.60753315854213, 'longitude': -...
# 16    {'latitude': 47.59974, 'longitude': -122.32614}
# 17    {'latitude': 47.60673, 'longitude': -122.31649}
# 18    {'latitude': 47.62063, 'longitude': -122.32134}
# 19    {'latitude': 47.61537, 'longitude': -122.32534}
#
#                 transactions price  \
# 0                 [delivery]    $$
# 1                 [delivery]  $$$$
# 2         [delivery, pickup]    $$
# 3         [delivery, pickup]  $$$$
# 4                 [delivery]    $$
# 5         [delivery, pickup]    $$
# 6                 [delivery]   $$$
# 7                 [delivery]   $$$
# 8   [restaurant_reservation]   NaN
# 9         [delivery, pickup]    $$
# 10        [delivery, pickup]    $$
# 11        [delivery, pickup]   NaN
# 12                [delivery]    $$
# 13        [delivery, pickup]    $$
# 14                        []    $$
# 15                [delivery]    $$
# 16                [delivery]    $$
# 17        [delivery, pickup]    $$
# 18                        []  $$$$
# 19        [delivery, pickup]    $$
#
#                                              location         phone  \
# 0   {'address1': '1400 1st Ave', 'address2': '', '...  +12069717979
# 1   {'address1': '86 Pine St', 'address2': 'Ste 1'...  +12064418844
# 2   {'address1': '1420 5th Ave', 'address2': '', '...  +12066828000
# 3   {'address1': '2401 2nd Ave', 'address2': '', '...  +12064439844
# 4   {'address1': '1522 12th Ave', 'address2': '', ...  +12064574068
# 5   {'address1': '2001 8th Ave', 'address2': 'Ste ...  +12064486953
# 6   {'address1': '724 Pine St', 'address2': '', 'a...  +14256582626
# 7   {'address1': '2230 1st Ave', 'address2': None,...  +12063748717
# 8   {'address1': '2001 Western Ave', 'address2': '...  +12062680172
# 9   {'address1': '2100 Western Ave', 'address2': '...  +12064534685
# 10  {'address1': '320 E Pike St', 'address2': '', ...  +12063279269
# 11  {'address1': '1202 Pine St', 'address2': '', '...  +12068907056
# 12  {'address1': '122 Westlake Ave N', 'address2':...  +12065800080
# 13  {'address1': '224 Broadway E', 'address2': '',...  +12065882051
# 14  {'address1': '731 Bell St', 'address2': None, ...  +12062571304
# 15  {'address1': '900 8th Ave', 'address2': '', 'a...  +12065882769
# 16  {'address1': '304 6th Ave S', 'address2': '', ...  +12066222631
# 17  {'address1': '514 12th Ave', 'address2': 'Acro...  +12063291112
# 18  {'address1': '219 Broadway E', 'address2': 'St...
# 19  {'address1': '500 E Pine St', 'address2': '', ...  +12069798800
#
#      display_phone     distance
# 0   (206) 971-7979   535.782040
# 1   (206) 441-8844   586.044184
# 2   (206) 682-8000   127.635824
# 3   (206) 443-9844  1062.601123
# 4   (206) 457-4068  1366.179557
# 5   (206) 448-6953   549.953671
# 6   (425) 658-2626   195.386342
# 7   (206) 374-8717   924.870199
# 8   (206) 268-0172   778.188897
# 9   (206) 453-4685   806.791837
# 10  (206) 327-9269   612.810300
# 11  (206) 890-7056   597.397745
# 12  (206) 580-0080   930.371750
# 13  (206) 588-2051  1438.975663
# 14  (206) 257-1304   856.160379
# 15  (206) 588-2769   636.408939
# 16  (206) 622-2631  1433.640395
# 17  (206) 329-1112  1412.399360
# 18                  1395.992798
# 19  (206) 979-8800   793.095109

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/results_per_page
# Out:
# 10.5

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/results_per_page)
n_pages
# Out:
# 11

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    # The block of code we want to TRY to run
    try:
        time.sleep(.2)
        
        # Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        # save number of results for to use as offset
        n_results = len(previous_results)
        
        
        # use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        # append new results and save to file
        previous_results.extend(results['businesses'])
        with open (JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    # What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                        alias                 name  \
# 0  3hxncVCRPfmKLOyiXKXbDw        sushi-kashiba-seattle        Sushi Kashiba
# 1  CwvRIblqSTc1McIE9hwhFA      sushi-kudasai-seattle-2        Sushi Kudasai
# 2  YSQiqH7RIWORk_Qp-A4SOg               shiros-seattle              Shiro's
# 3  vs5dhED5Yf8kqPp06OD2QQ               momiji-seattle               Momiji
# 4  L5AL3EIl085kjESUj0POfQ  urban-sushi-kitchen-seattle  Urban Sushi Kitchen
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-m...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/fXSJAz...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/Gs9xeF...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6B...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/9zhNuE...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sushi-kashiba-seattle...          1382
# 1  https://www.yelp.com/biz/sushi-kudasai-seattle...           145
# 2  https://www.yelp.com/biz/shiros-seattle?adjust...          2586
# 3  https://www.yelp.com/biz/momiji-seattle?adjust...          1798
# 4  https://www.yelp.com/biz/urban-sushi-kitchen-s...           158
#
#                                           categories  rating  \
# 0  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 2  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 3  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 4  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 47.6099251, 'longitude': -122.341...          [delivery]
# 1  {'latitude': 47.610282, 'longitude': -122.333958}  [pickup, delivery]
# 2  {'latitude': 47.6147782162181, 'longitude': -1...  [delivery, pickup]
# 3    {'latitude': 47.61482, 'longitude': -122.31657}          [delivery]
# 4  {'latitude': 47.61590895201695, 'longitude': -...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0  $$$$  {'address1': '86 Pine St', 'address2': 'Ste 1'...  +12064418844
# 1    $$  {'address1': '1420 5th Ave', 'address2': '', '...  +12066828000
# 2  $$$$  {'address1': '2401 2nd Ave', 'address2': '', '...  +12064439844
# 3    $$  {'address1': '1522 12th Ave', 'address2': '', ...  +12064574068
# 4    $$  {'address1': '2001 8th Ave', 'address2': 'Ste ...  +12064486953
#
#     display_phone     distance
# 0  (206) 441-8844   586.044184
# 1  (206) 682-8000   127.635824
# 2  (206) 443-9844  1062.601123
# 3  (206) 457-4068  1366.179557
# 4  (206) 448-6953   549.953671

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             209 non-null    object
#  1   alias          209 non-null    object
#  2   name           209 non-null    object
#  3   image_url      209 non-null    object
#  4   is_closed      209 non-null    bool
#  5   url            209 non-null    object
#  6   review_count   209 non-null    int64
#  7   categories     209 non-null    object
#  8   rating         209 non-null    float64
#  9   coordinates    209 non-null    object
#  10  transactions   209 non-null    object
#  11  price          187 non-null    object
#  12  location       209 non-null    object
#  13  phone          209 non-null    object
#  14  display_phone  209 non-null    object
#  15  distance       209 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 24.8+ KB

# %%
# Convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Seattle-sushi.csv.gz'

# %%
# Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
